# %%
import pandas as pd
from sqlalchemy import create_engine
import psycopg2 
import requests
from json import load
import json

# %% [markdown]
# ## Understanding the JSON schema from DataBase

# %%
# Loading Schema
with open('Agri_schema.json', "r") as sc:
    schema = load(sc)
    
    pretty_json = json.dumps(schema, indent=3)
    print(pretty_json)
# Out:
# {
#    "title": "agri-environmental-indicators-emissions-by-sector",
#    "type": "object",
#    "oneOf": [
#       {
#          "$ref": "#/definitions/agri-environmental-indicators-emissions-by-sector"
#       }
#    ],
#    "definitions": {
#       "agri-environmental-indicators-emissions-by-sector": {
#          "properties": {
#             "records": {
#                "type": "array",
#                "items": {
#                   "$ref": "#/definitions/agri-environmental-indicators-emissions-by-sector_records"
#                }
#             }
#          }
#       },
#       "agri-environmental-indicators-emissions-by-sector_records": {
#          "properties": {
#             "fields": {
#                "type": "object",
#                "properties": {
#                   "year": {
#                      "type": "string",
#                      "format": "date",
#                      "title": "Year",
#                      "description": ""
#                   },
#                   "area": {
#                      "type": "string",
#                      "title": "Area",
#                      "description": ""
#                   },
#                   "item": {
#                      "type": "string",
#                      "title": "Item",
#                      "description": ""
#                   },
#                   "element": {
#                      "type": "string",
#                      "title": "Element",
#                      "description": ""
#                   },
#                   "value": {
#                      "type": "number",
#                      "title": "Value",
#                      "description": ""
#                   },
#                   "unit": {
#                      "type": "string",
#                      "title": "Unit",
#                      "description": ""
#                   }
#                }
#             }
#          }
#       }
#    }
# }

# %% [markdown]
# # Open JSON file - Download file from link in Readme or Resources

# %%
json_file ="agri-environmental-indicators-emissions-by-sector.json"

# %%
entire_file_df = pd.read_json(json_file)
entire_file_df.head()
# Out:
#                                            datasetid  \
# 0  agri-environmental-indicators-emissions-by-sector
# 1  agri-environmental-indicators-emissions-by-sector
# 2  agri-environmental-indicators-emissions-by-sector
# 3  agri-environmental-indicators-emissions-by-sector
# 4  agri-environmental-indicators-emissions-by-sector
#
#                                    recordid  \
# 0  5500592b928d56fc0da60501fa364fa5c132b79a
# 1  6b85b6ddf5ef6956602f5794450b16671561f5ff
# 2  7315471f71541c41f2a5349f7bb4b522a051931f
# 3  825a93245b1d222469a12604a1651cc34a63bd52
# 4  3f4119c9755d2fddac4126a472f149131a6bace1
#
#                                               fields  \
# 0  {'year': '2014', 'element': 'Emissions (F-gase...
# 1  {'year': '2018', 'element': 'Emissions (F-gase...
# 2  {'year': '1991', 'element': 'Emissions Share (...
# 3  {'year': '1999', 'element': 'Emissions Share (...
# 4  {'year': '2012', 'element': 'Emissions Share (...
#
#                 record_timestamp
# 0  2021-11-07T05:29:57.595-06:00
# 1  2021-11-07T05:29:57.595-06:00
# 2  2021-11-07T05:29:57.595-06:00
# 3  2021-11-07T05:29:57.595-06:00
# 4  2021-11-07T05:29:57.595-06:00

# %%
fields_df = entire_file_df.loc[:, "fields"]
fields_df.head()
# Out:
# 0    {'year': '2014', 'element': 'Emissions (F-gase...
# 1    {'year': '2018', 'element': 'Emissions (F-gase...
# 2    {'year': '1991', 'element': 'Emissions Share (...
# 3    {'year': '1999', 'element': 'Emissions Share (...
# 4    {'year': '2012', 'element': 'Emissions Share (...
# Name: fields, dtype: object

# %% [markdown]
# ### Make a Usable DataFrame

# %%
ent_json = pd.json_normalize(fields_df)
ent_json
# Out:
#          year                        element        unit           area  \
# 0        2014            Emissions (F-gases)  kilotonnes       Mongolia
# 1        2018            Emissions (F-gases)  kilotonnes       Mongolia
# 2        1991  Emissions Share (CO2eq) (AR5)           %       Mongolia
# 3        1999  Emissions Share (CO2eq) (AR5)           %       Mongolia
# 4        2012  Emissions Share (CO2eq) (AR5)           %       Mongolia
# ...       ...                            ...         ...            ...
# 1683943  2000                Emissions (N2O)  kilotonnes  South America
# 1683944  2011                Emissions (N2O)  kilotonnes  South America
# 1683945  2016                Emissions (N2O)  kilotonnes  South America
# 1683946  1992            Emissions (F-gases)  kilotonnes  South America
# 1683947  1994            Emissions (F-gases)  kilotonnes  South America
#
#                                item    value
# 0              Waste - food systems   0.0000
# 1              Waste - food systems   0.0000
# 2        Food Household Consumption   0.9332
# 3        Food Household Consumption   0.3126
# 4        Food Household Consumption   0.6152
# ...                             ...      ...
# 1683943        Waste - food systems   9.9872
# 1683944        Waste - food systems  13.0647
# 1683945        Waste - food systems  12.9916
# 1683946        Waste - food systems   0.0000
# 1683947        Waste - food systems   0.0000
#
# [1683948 rows x 6 columns]

# %% [markdown]
# ### Selecting Major 50 countries Representating Emissions DataBase

# %%
counrty_list = ['United States', 'Mexico', 'Brazil', 'Columbia', 'Venezuela','Chile','Peru','India','Bangladesh','Sri Lanka',
                'Myanmar', 'Pakistan', 'Russia', 'Ukraine', 'Kazakhstan', 'Azerbaijan', 'Armenia', 'Afghanistan', 'Uzbekistan',
                'South Africa', 'Nigeria', 'Ghana', 'Morocco', 'Egypt', 'Kenya', 'China', 'Japan', 'Hong Kong', 'Singapore', 
                'Thailand', 'Malaysia', 'Korea', 'Viet Nam', 'United Kingdom', 'France', 'Germany', 'Norway', 'Italy', 
                'Spain', 'Portugal', 'Sweden', 'Turkey', 'Greece', 'Saudi Arabia', 'Bahrain', 'Syrian Arab Republic', 
                'Iraq', 'Qatar', 'United Arab Emirates', 'Kuwait']

# %%
Agri_emis_cntry = ent_json.loc[ent_json["area"].isin(counrty_list)]
Agri_emis_cntry
# Out:
#          year                  element        unit       area  \
# 697      2000    Emissions Share (CO2)           %     Mexico
# 698      2009    Emissions Share (CO2)           %     Mexico
# 699      2013    Emissions Share (CO2)           %     Mexico
# 700      2016    Emissions Share (CO2)           %     Mexico
# 701      2018    Emissions Share (CO2)           %     Mexico
# ...       ...                      ...         ...        ...
# 1680933  1991  Emissions (CO2eq) (AR5)  kilotonnes  Sri Lanka
# 1680934  1996  Emissions (CO2eq) (AR5)  kilotonnes  Sri Lanka
# 1680935  1997  Emissions (CO2eq) (AR5)  kilotonnes  Sri Lanka
# 1680936  2016  Emissions (CO2eq) (AR5)  kilotonnes  Sri Lanka
# 1680937  2004          Emissions (CO2)  kilotonnes  Sri Lanka
#
#                           item      value
# 697      Energy - food systems    12.4978
# 698      Energy - food systems    12.8555
# 699      Energy - food systems    11.8992
# 700      Energy - food systems    12.5585
# 701      Energy - food systems    13.1745
# ...                        ...        ...
# 1680933                 LULUCF  4648.9348
# 1680934                 LULUCF  4678.1061
# 1680935                 LULUCF  4646.0924
# 1680936                 LULUCF  1923.3412
# 1680937                 LULUCF  2505.1741
#
# [302728 rows x 6 columns]

# %% [markdown]
# ### Cleaning Data

# %%
Agri_emis_cntry = Agri_emis_cntry.dropna(how='any')
Agri_emis_cntry.reset_index(drop = True, inplace = True)
Agri_emis_cntry
# Out:
#         year                  element        unit       area  \
# 0       2000    Emissions Share (CO2)           %     Mexico
# 1       2009    Emissions Share (CO2)           %     Mexico
# 2       2013    Emissions Share (CO2)           %     Mexico
# 3       2016    Emissions Share (CO2)           %     Mexico
# 4       2018    Emissions Share (CO2)           %     Mexico
# ...      ...                      ...         ...        ...
# 302723  1991  Emissions (CO2eq) (AR5)  kilotonnes  Sri Lanka
# 302724  1996  Emissions (CO2eq) (AR5)  kilotonnes  Sri Lanka
# 302725  1997  Emissions (CO2eq) (AR5)  kilotonnes  Sri Lanka
# 302726  2016  Emissions (CO2eq) (AR5)  kilotonnes  Sri Lanka
# 302727  2004          Emissions (CO2)  kilotonnes  Sri Lanka
#
#                          item      value
# 0       Energy - food systems    12.4978
# 1       Energy - food systems    12.8555
# 2       Energy - food systems    11.8992
# 3       Energy - food systems    12.5585
# 4       Energy - food systems    13.1745
# ...                       ...        ...
# 302723                 LULUCF  4648.9348
# 302724                 LULUCF  4678.1061
# 302725                 LULUCF  4646.0924
# 302726                 LULUCF  1923.3412
# 302727                 LULUCF  2505.1741
#
# [302728 rows x 6 columns]

# %% [markdown]
# ### Understanding the various industry Sectors used in Emissions data

# %%
Agri_emis_sector = Agri_emis_cntry['item'].value_counts()
Agri_emis_sector_df = pd.DataFrame(Agri_emis_sector)
Agri_emis_sector_df
# Out:
#                                  item
# Food Transport                  12593
# Farm-gate emissions             12593
# On-farm electricity use         12593
# All sectors without LULUCF      12593
# Food Household Consumption      12593
# Waste - food systems            12593
# Food Waste Disposal             12593
# IPCC Agriculture                12593
# Energy                          12593
# Emissions on agricultural land  12593
# Pre- and post- production       12593
# AFOLU                           12593
# All sectors with LULUCF         12593
# Energy - food systems           12593
# Food systems                    12593
# Food Processing                 12593
# LULUCF                          12593
# Land Use change                 12593
# Food Packaging                  12581
# LULUCF - food systems           12533
# IPPU                            12037
# Waste                           11525
# Food Retail                     10224
# Other                            7713
# Fertilizers Manufacturing        6361
# IPPU - food systems              3080

# %% [markdown]
# ### Pushing Industry / Sectors out to CSV

# %%
Agri_emis_sector_df.to_csv("Agri_emis_by_Sector.csv", index= True, header = True)

# %% [markdown]
# ### Understanding the various compounds used in emssions database

# %%
Agri_emis_gases = Agri_emis_cntry['element'].value_counts()
Agri_emis_gases_df = pd.DataFrame(Agri_emis_gases)
Agri_emis_gases_df
# Out:
#                                element
# Emissions Share (CO2eq) (AR5)    32239
# Emissions (CO2eq) (AR5)          32239
# Emissions (F-gases)              31650
# Emissions Share (N2O)            31139
# Emissions (N2O)                  31139
# Emissions Share (CO2)            29586
# Emissions (CO2)                  29586
# Emissions (CH4)                  29098
# Emissions Share (CH4)            29098
# Emissions Share (F-gases)        26954

# %% [markdown]
# # Since "Emission Share" has a unit of % whereas normal emissions are measured in kilotonnes it is thought that 2 separate dataframes would be beneficial for loading into Database for Query purposes - one with % emissions and other with actual value

# %% [markdown]
# ### Making the 1st Dataframe that represents % emissions of the 50 selected countries

# %%
Agri_em_percent = Agri_emis_cntry.loc[(Agri_emis_cntry["element"] == "Emissions Share (CO2eq) (AR5)") | 
                                      (Agri_emis_cntry["element"] == "Emissions Share (N2O)") |
                                        (Agri_emis_cntry["element"] == "Emissions Share (CO2)") |
                                      (Agri_emis_cntry["element"] == "Emissions Share (CH4)") |
                                       (Agri_emis_cntry["element"] == "Emissions Share (F-gases)"), :]
Agri_em_percent.reset_index(drop = True, inplace = True)
Agri_em_percent
# Out:
#         year                element unit       area                   item  \
# 0       2000  Emissions Share (CO2)    %     Mexico  Energy - food systems
# 1       2009  Emissions Share (CO2)    %     Mexico  Energy - food systems
# 2       2013  Emissions Share (CO2)    %     Mexico  Energy - food systems
# 3       2016  Emissions Share (CO2)    %     Mexico  Energy - food systems
# 4       2018  Emissions Share (CO2)    %     Mexico  Energy - food systems
# ...      ...                    ...  ...        ...                    ...
# 149011  2001  Emissions Share (N2O)    %  Sri Lanka                 LULUCF
# 149012  2004  Emissions Share (N2O)    %  Sri Lanka                 LULUCF
# 149013  2012  Emissions Share (N2O)    %  Sri Lanka                 LULUCF
# 149014  2016  Emissions Share (N2O)    %  Sri Lanka                 LULUCF
# 149015  2018  Emissions Share (N2O)    %  Sri Lanka                 LULUCF
#
#           value
# 0       12.4978
# 1       12.8555
# 2       11.8992
# 3       12.5585
# 4       13.1745
# ...         ...
# 149011   0.0000
# 149012   0.0259
# 149013   0.0614
# 149014   0.0475
# 149015   0.0000
#
# [149016 rows x 6 columns]

# %% [markdown]
# ### Renaming & Organizing columns

# %%
Rename_Agri_em_percent = Agri_em_percent.rename(columns = {"area": "Country", "value":"Percent_Glb_Agri_Emission", "element":"GH-gases", "item": "Agri_Industry_Sector" })
Org_agri_emi_per = Rename_Agri_em_percent[["year", "Country", "GH-gases", "Agri_Industry_Sector", "Percent_Glb_Agri_Emission", "unit"]]
Org_agri_emi_per
# Out:
#         year    Country               GH-gases   Agri_Industry_Sector  \
# 0       2000     Mexico  Emissions Share (CO2)  Energy - food systems
# 1       2009     Mexico  Emissions Share (CO2)  Energy - food systems
# 2       2013     Mexico  Emissions Share (CO2)  Energy - food systems
# 3       2016     Mexico  Emissions Share (CO2)  Energy - food systems
# 4       2018     Mexico  Emissions Share (CO2)  Energy - food systems
# ...      ...        ...                    ...                    ...
# 149011  2001  Sri Lanka  Emissions Share (N2O)                 LULUCF
# 149012  2004  Sri Lanka  Emissions Share (N2O)                 LULUCF
# 149013  2012  Sri Lanka  Emissions Share (N2O)                 LULUCF
# 149014  2016  Sri Lanka  Emissions Share (N2O)                 LULUCF
# 149015  2018  Sri Lanka  Emissions Share (N2O)                 LULUCF
#
#         Percent_Glb_Agri_Emission unit
# 0                         12.4978    %
# 1                         12.8555    %
# 2                         11.8992    %
# 3                         12.5585    %
# 4                         13.1745    %
# ...                           ...  ...
# 149011                     0.0000    %
# 149012                     0.0259    %
# 149013                     0.0614    %
# 149014                     0.0475    %
# 149015                     0.0000    %
#
# [149016 rows x 6 columns]

# %% [markdown]
# ### Deleting rows with 0 emmisions and Finalizing DataFrame for loading into SQL

# %%
del Org_agri_emi_per['unit']
final_agri_em_per_df = Org_agri_emi_per.loc[(Org_agri_emi_per["Percent_Glb_Agri_Emission"]>0), :]
final_agri_em_per_df = final_agri_em_per_df.sort_values("year")
final_agri_em_per_df.reset_index (drop =True, inplace = True)
final_agri_em_per_df
# Out:
#         year     Country                       GH-gases  \
# 0       1990       Egypt  Emissions Share (CO2eq) (AR5)
# 1       1990       Japan  Emissions Share (CO2eq) (AR5)
# 2       1990       Japan          Emissions Share (CH4)
# 3       1990       Japan          Emissions Share (N2O)
# 4       1990        Peru          Emissions Share (N2O)
# ...      ...         ...                            ...
# 115243  2019  Azerbaijan          Emissions Share (CO2)
# 115244  2019    Portugal      Emissions Share (F-gases)
# 115245  2019  Azerbaijan  Emissions Share (CO2eq) (AR5)
# 115246  2019  Bangladesh          Emissions Share (CH4)
# 115247  2019     Armenia  Emissions Share (CO2eq) (AR5)
#
#               Agri_Industry_Sector  Percent_Glb_Agri_Emission
# 0                           Energy                    66.7577
# 1       All sectors without LULUCF                   106.3107
# 2          All sectors with LULUCF                   100.0000
# 3                   Food Packaging                     0.2160
# 4              Food Waste Disposal                     1.9951
# ...                            ...                        ...
# 115243     On-farm electricity use                     1.6114
# 115244   Pre- and post- production                     3.0105
# 115245     On-farm electricity use                     1.0351
# 115246                        IPPU                     0.0001
# 115247              Food Transport                     1.3281
#
# [115248 rows x 5 columns]

# %%
final_agri_em_per_df.count()
# Out:
# year                         115248
# Country                      115248
# GH-gases                     115248
# Agri_Industry_Sector         115248
# Percent_Glb_Agri_Emission    115248
# dtype: int64

# %% [markdown]
# ### Making 2nd Dataframe which represents actual values of emissions in Kilotonnes

# %%
Agri_em_actual = Agri_emis_cntry.loc[(Agri_emis_cntry["element"] == "Emissions (CO2eq) (AR5)") | 
                                      (Agri_emis_cntry["element"] == "Emissions (N2O)") |
                                        (Agri_emis_cntry["element"] == "Emissions (CO2)") |
                                      (Agri_emis_cntry["element"] == "Emissions (CH4)")|
                                     (Agri_emis_cntry["element"] == "Emissions (F-gases)"), :]
Agri_em_actual.reset_index(drop = True, inplace = True)
Rename_Agri_em_actual = Agri_em_actual.rename(columns = {"area": "Country", "value":"Glb_Agri_Emission_ktonnes", "element":"GH-gases", "item": "Agri_Industry_Sector" })
Org_agri_emi_act = Rename_Agri_em_actual[["year", "Country", "GH-gases", "Agri_Industry_Sector", "Glb_Agri_Emission_ktonnes", "unit"]]
del Org_agri_emi_act['unit']
final_agri_em_act_df = Org_agri_emi_act.loc[(Org_agri_emi_act["Glb_Agri_Emission_ktonnes"]>0), :]
final_agri_em_act_df.reset_index (drop =True, inplace = True)
final_agri_em_act_df= final_agri_em_act_df.sort_values("year")
final_agri_em_act_df
# Out:
#         year               Country                 GH-gases  \
# 91168   1990  United Arab Emirates          Emissions (CO2)
# 89735   1990  Syrian Arab Republic          Emissions (CO2)
# 89761   1990              Viet Nam  Emissions (CO2eq) (AR5)
# 13053   1990                Sweden          Emissions (CH4)
# 43371   1990              Portugal          Emissions (N2O)
# ...      ...                   ...                      ...
# 1381    2019                 Chile          Emissions (CH4)
# 84582   2019                Sweden          Emissions (CH4)
# 112260  2019          South Africa  Emissions (CO2eq) (AR5)
# 96583   2019              Pakistan          Emissions (CH4)
# 104931  2019                 Kenya          Emissions (CO2)
#
#               Agri_Industry_Sector  Glb_Agri_Emission_ktonnes
# 91168          Farm-gate emissions                  3256.9086
# 89735   Food Household Consumption                   504.7280
# 89761                         IPPU                  1310.2623
# 13053      All sectors with LULUCF                   571.0949
# 43371      All sectors with LULUCF                    14.4681
# ...                            ...                        ...
# 1381    Food Household Consumption                     6.0095
# 84582        Energy - food systems                    20.6405
# 112260                      LULUCF                  6753.3552
# 96583               Food Packaging                     0.2140
# 104931                       Waste                     1.2200
#
# [115763 rows x 5 columns]

# %%
final_agri_em_act_df.count()
# Out:
# year                         115763
# Country                      115763
# GH-gases                     115763
# Agri_Industry_Sector         115763
# Glb_Agri_Emission_ktonnes    115763
# dtype: int64

# %% [markdown]
# ### Using Postgresql to populate the tables in sSQL with data

# %%
from config import password

# %%
protocol = 'postgresql'
username = 'postgres'
host = 'localhost'
port = 5432
database_name = 'Global_Emissions'
rds_connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'
engine = create_engine(rds_connection_string)
# connection = engine.connect()

# %%
engine.table_names()
# Out:
# ['Global_oil_data_iea',
#  'Global_oil_demand',
#  'Global_Greenhouse_Emissions',
#  'Global_Agri_Greenhouse_Emissions',
#  'Global_Agri_Percent_Emissions']

# %% [markdown]
# ### Current writing to SQL is set at "replace" - use "append" to add to SLQ database for additional countries

# %%
final_agri_em_act_df.to_sql(name='Global_Agri_Greenhouse_Emissions', con=engine, if_exists='replace', index=False)

# %%
final_agri_em_per_df.to_sql(name='Global_Agri_Percent_Emissions', con=engine, if_exists='replace', index=False)

# %%
pd.read_sql_query('select * from "Global_Agri_Greenhouse_Emissions"', con=engine).head()
# Out:
#    year               Country                 GH-gases  \
# 0  1990  United Arab Emirates          Emissions (CO2)
# 1  1990  Syrian Arab Republic          Emissions (CO2)
# 2  1990              Viet Nam  Emissions (CO2eq) (AR5)
# 3  1990                Sweden          Emissions (CH4)
# 4  1990              Portugal          Emissions (N2O)
#
#          Agri_Industry_Sector  Glb_Agri_Emission_ktonnes
# 0         Farm-gate emissions                  3256.9086
# 1  Food Household Consumption                   504.7280
# 2                        IPPU                  1310.2623
# 3     All sectors with LULUCF                   571.0949
# 4     All sectors with LULUCF                    14.4681

# %%
pd.read_sql_query('select * from "Global_Agri_Percent_Emissions"', con=engine).head()
# Out:
#    year Country                       GH-gases        Agri_Industry_Sector  \
# 0  1990   Egypt  Emissions Share (CO2eq) (AR5)                      Energy
# 1  1990   Japan  Emissions Share (CO2eq) (AR5)  All sectors without LULUCF
# 2  1990   Japan          Emissions Share (CH4)     All sectors with LULUCF
# 3  1990   Japan          Emissions Share (N2O)              Food Packaging
# 4  1990    Peru          Emissions Share (N2O)         Food Waste Disposal
#
#    Percent_Glb_Agri_Emission
# 0                    66.7577
# 1                   106.3107
# 2                   100.0000
# 3                     0.2160
# 4                     1.9951
