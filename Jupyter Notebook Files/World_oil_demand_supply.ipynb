# %%
import pandas as pd
from sqlalchemy import create_engine
import psycopg2 
import requests

# %%
world_oil_data ="iea-oil-market-report-2001-2016.csv"
worldoil_alldata = pd.read_csv(world_oil_data)
worldoil_alldata.head()
# Out:
#       DATE FREQUENCY REGION_NAME  INDICATOR_NAME  VALUE INDICATOR_ID  \
# 0  2017-06   Monthly       Japan  Total products   85.7       KN.B47
# 1  2018-07   Monthly       Japan  Total products   80.1       KN.B47
# 2  2018-08   Monthly       Japan  Total products   87.0       KN.B47
# 3  2019-02   Monthly       Japan  Total products   82.4       KN.B47
# 4  2019-07   Monthly       Japan  Total products   85.3       KN.B47
#
#   REGION_ID REGION_NOTES REGION_REGIONID
# 0        JP          NaN              JP
# 1        JP          NaN              JP
# 2        JP          NaN              JP
# 3        JP          NaN              JP
# 4        JP          NaN              JP

# %%
worldoil_alldata.count()
# Out:
# DATE               24969
# FREQUENCY          24969
# REGION_NAME        24969
# INDICATOR_NAME     24969
# VALUE              24969
# INDICATOR_ID       24969
# REGION_ID          24969
# REGION_NOTES          31
# REGION_REGIONID    24969
# dtype: int64

# %%
worldoil_alldata.dtypes
# Out:
# DATE                object
# FREQUENCY           object
# REGION_NAME         object
# INDICATOR_NAME      object
# VALUE              float64
# INDICATOR_ID        object
# REGION_ID           object
# REGION_NOTES        object
# REGION_REGIONID     object
# dtype: object

# %%
abc = worldoil_alldata.DATE.str.split('-').tolist()
abc
# Out:
# [['2017', '06'],
#  ['2018', '07'],
#  ['2018', '08'],
#  ['2019', '02'],
#  ['2019', '07'],
#  ['2020', '03'],
#  ['2020', '06'],
#  ['2020', '07'],
#  ['2020', '08'],
#  ['2020', '12'],
#  ['2016', '10'],
#  ['2016', '12'],
#  ['2017', '01'],
#  ['2017', '10'],
#  ['2018', '01'],
#  ['2018', '07'],
#  ['2018', '10'],
#  ['2018', '12'],
#  ['2019', '04'],
#  ['2019', '07'],
#  ['2019', '12'],
#  ['2020', '01'],
#  ['2020', '08'],
#  ['2020', '12'],
#  ['2016', '07'],
#  ['2016', '09'],
#  ['2016', '11'],
#  ['2017', '05'],
#  ['2018', '04'],
#  ['2018', '06'],
#  ['2018', '10'],
#  ['2019', '01'],
#  ['2019', '08'],
#  ['2020', '02'],
#  ['2020', '04'],
#  ['2020', '07'],
#  ['2016', '10'],
#  ['2016', '12'],
#  ['2017', '06'],
#  ['2018', '04'],
#  ['2018', '11'],
#  ['2020', '06'],
#  ['2020', '08'],
#  ['2020', '12'],
#  ['2010', '01'],
#  ['2012', '01'],
#  ['2007', '01'],
#  ['2010', '01'],
#  ['2003', '11'],
#  ['2003', '12'],
#  ['2004', '01'],
#  ['2004', '04'],
#  ['2004', '07'],
#  ['2005', '01'],
#  ['2005', '02'],
#  ['2005', '05'],
#  ['2005', '09'],
#  ['2007', '12'],
#  ['2008', '06'],
#  ['2009', '01'],
#  ['2009', '02'],
#  ['2009', '06'],
#  ['2009', '12'],
#  ['2010', '04'],
#  ['2010', '07'],
#  ['2010', '08'],
#  ['2011', '04'],
#  ['2011', '05'],
#  ['2011', '11'],
#  ['2012', '02'],
#  ['2005', '01'],
#  ['2006', '01'],
#  ['2011', '01'],
#  ['2004', '07'],
#  ['2005', '10'],
#  ['2007', '07'],
#  ['2008', '01'],
#  ['2008', '07'],
#  ['2010', '04'],
#  ['2010', '07'],
#  ['2003', '12'],
#  ['2004', '04'],
#  ['2005', '03'],
#  ['2005', '06'],
#  ['2005', '09'],
#  ['2007', '02'],
#  ['2007', '04'],
#  ['2007', '05'],
#  ['2007', '09'],
#  ['2008', '05'],
#  ['2008', '08'],
#  ['2009', '10'],
#  ['2010', '09'],
#  ['2010', '12'],
#  ['2011', '02'],
#  ['2011', '03'],
#  ['2011', '10'],
#  ['2003', '10'],
#  ['2005', '01'],
#  ['2006', '01'],
#  ['2007', '04'],
#  ['2010', '01'],
#  ['2011', '07'],
#  ['2004', '01'],
#  ['2004', '04'],
#  ['2004', '06'],
#  ['2006', '05'],
#  ['2006', '06'],
#  ['2006', '09'],
#  ['2006', '11'],
#  ['2007', '09'],
#  ['2008', '05'],
#  ['2008', '06'],
#  ['2008', '08'],
#  ['2008', '12'],
#  ['2009', '02'],
#  ['2009', '05'],
#  ['2010', '03'],
#  ['2010', '12'],
#  ['2011', '02'],
#  ['2011', '03'],
#  ['2011', '05'],
#  ['2011', '09'],
#  ['2011', '10'],
#  ['2012', '03'],
#  ['2004', '02'],
#  ['2004', '05'],
#  ['2004', '11'],
#  ['2005', '04'],
#  ['2005', '07'],
#  ['2006', '03'],
#  ['2006', '04'],
#  ['2007', '10'],
#  ['2009', '02'],
#  ['2009', '04'],
#  ['2009', '12'],
#  ['2011', '03'],
#  ['2012', '01'],
#  ['2012', '02'],
#  ['2004', '10'],
#  ['2005', '01'],
#  ['2005', '07'],
#  ['2006', '07'],
#  ['2006', '10'],
#  ['2007', '01'],
#  ['2008', '01'],
#  ['2010', '04'],
#  ['2010', '07'],
#  ['2003', '12'],
#  ['2004', '07'],
#  ['2005', '02'],
#  ['2006', '02'],
#  ['2006', '03'],
#  ['2006', '06'],
#  ['2006', '09'],
#  ['2006', '10'],
#  ['2008', '04'],
#  ['2008', '12'],
#  ['2009', '02'],
#  ['2009', '03'],
#  ['2009', '04'],
#  ['2010', '01'],
#  ['2010', '02'],
#  ['2010', '05'],
#  ['2010', '06'],
#  ['2010', '07'],
#  ['2010', '12'],
#  ['2011', '02'],
#  ['2011', '10'],
#  ['2006', '04'],
#  ['2008', '04'],
#  ['2010', '07'],
#  ['2010', '10'],
#  ['2012', '01'],
#  ['2004', '01'],
#  ['2007', '01'],
#  ['2008', '01'],
#  ['2005', '05'],
#  ['2006', '05'],
#  ['2006', '08'],
#  ['2007', '01'],
#  ['2008', '05'],
#  ['2009', '05'],
#  ['2009', '06'],
#  ['2009', '07'],
#  ['2010', '02'],
#  ['2010', '03'],
#  ['2010', '05'],
#  ['2011', '05'],
#  ['2011', '06'],
#  ['2011', '10'],
#  ['2012', '02'],
#  ['2006', '07'],
#  ['2008', '07'],
#  ['2010', '07'],
#  ['2010', '10'],
#  ['2011', '01'],
#  ['2013', '01'],
#  ['2020', '01'],
#  ['2020', '01'],
#  ['2016', '07'],
#  ['2018', '07'],
#  ['2019', '04'],
#  ['2019', '07'],
#  ['2021', '01'],
#  ['2021', '04'],
#  ['2021', '10'],
#  ['2016', '01'],
#  ['2016', '07'],
#  ['2017', '12'],
#  ['2018', '06'],
#  ['2018', '07'],
#  ['2018', '10'],
#  ['2019', '07'],
#  ['2019', '10'],
#  ['2020', '01'],
#  ['2020', '03'],
#  ['2021', '01'],
#  ['2018', '10'],
#  ['2019', '01'],
#  ['2019', '10'],
#  ['2020', '01'],
#  ['2021', '01'],
#  ['2016', '01'],
#  ['2018', '01'],
#  ['2016', '07'],
#  ['2017', '07'],
#  ['2018', '04'],
#  ['2018', '07'],
#  ['2019', '01'],
#  ['2019', '07'],
#  ['2021', '01'],
#  ['2021', '04'],
#  ['2016', '01'],
#  ['2016', '07'],
#  ['2016', '10'],
#  ['2017', '07'],
#  ['2018', '01'],
#  ['2016', '01'],
#  ['2017', '10'],
#  ['2019', '04'],
#  ['2018', '01'],
#  ['2007', '07'],
#  ['2008', '01'],
#  ['2008', '04'],
#  ['2010', '01'],
#  ['2010', '10'],
#  ['2013', '01'],
#  ['2013', '07'],
#  ['2016', '01'],
#  ['2016', '01'],
#  ['2017', '10'],
#  ['2018', '01'],
#  ['2018', '03'],
#  ['2018', '12'],
#  ['2019', '11'],
#  ['2020', '03'],
#  ['2020', '12'],
#  ['2019', '10'],
#  ['2020', '01'],
#  ['2020', '07'],
#  ['2005', '04'],
#  ['2008', '01'],
#  ['2009', '07'],
#  ['2010', '01'],
#  ['2010', '04'],
#  ['2012', '07'],
#  ['2013', '01'],
#  ['2015', '04'],
#  ['2020', '10'],
#  ['2021', '01'],
#  ['2021', '07'],
#  ['2005', '08'],
#  ['2005', '12'],
#  ['2007', '01'],
#  ['2007', '05'],
#  ['2007', '06'],
#  ['2007', '11'],
#  ['2008', '08'],
#  ['2009', '08'],
#  ['2009', '10'],
#  ['2009', '11'],
#  ['2010', '04'],
#  ['2010', '12'],
#  ['2011', '01'],
#  ['2011', '04'],
#  ['2011', '07'],
#  ['2012', '01'],
#  ['2012', '06'],
#  ['2013', '05'],
#  ['2013', '06'],
#  ['2013', '11'],
#  ['2014', '01'],
#  ['2014', '07'],
#  ['2014', '12'],
#  ['2015', '01'],
#  ['2016', '01'],
#  ['2017', '01'],
#  ['2020', '07'],
#  ['2021', '07'],
#  ['2018', '01'],
#  ['2021', '01'],
#  ['2005', '07'],
#  ['2006', '07'],
#  ['2007', '07'],
#  ['2009', '07'],
#  ['2012', '04'],
#  ['2012', '07'],
#  ['2014', '04'],
#  ['2014', '01'],
#  ['2015', '01'],
#  ['2021', '01'],
#  ['2016', '04'],
#  ['2017', '01'],
#  ['2017', '04'],
#  ['2018', '04'],
#  ['2018', '10'],
#  ['2021', '04'],
#  ['2021', '07'],
#  ['2015', '01'],
#  ['2016', '01'],
#  ['2016', '01'],
#  ['2018', '06'],
#  ['2018', '07'],
#  ['2018', '11'],
#  ['2019', '05'],
#  ['2019', '09'],
#  ['2020', '06'],
#  ['2020', '12'],
#  ['2018', '07'],
#  ['2019', '01'],
#  ['2020', '04'],
#  ['2004', '10'],
#  ['2005', '04'],
#  ['2008', '07'],
#  ['2009', '01'],
#  ['2009', '07'],
#  ['2010', '04'],
#  ['2013', '07'],
#  ['2013', '10'],
#  ['2017', '12'],
#  ['2018', '08'],
#  ['2018', '09'],
#  ['2018', '12'],
#  ['2019', '02'],
#  ['2019', '10'],
#  ['2020', '06'],
#  ['2020', '07'],
#  ['2017', '10'],
#  ['2018', '07'],
#  ['2019', '07'],
#  ['2020', '07'],
#  ['2005', '01'],
#  ['2009', '01'],
#  ['2016', '01'],
#  ['2005', '04'],
#  ['2005', '09'],
#  ['2006', '05'],
#  ['2006', '10'],
#  ['2007', '09'],
#  ['2008', '02'],
#  ['2008', '09'],
#  ['2009', '07'],
#  ['2010', '05'],
#  ['2010', '10'],
#  ['2010', '12'],
#  ['2011', '04'],
#  ['2011', '05'],
#  ['2012', '03'],
#  ['2012', '10'],
#  ['2013', '01'],
#  ['2013', '03'],
#  ['2013', '09'],
#  ['2013', '12'],
#  ['2014', '05'],
#  ['2014', '07'],
#  ['2014', '08'],
#  ['2010', '04'],
#  ['2011', '01'],
#  ['2013', '04'],
#  ['2014', '01'],
#  ['2014', '10'],
#  ['2015', '10'],
#  ['2016', '01'],
#  ['2017', '12'],
#  ['2018', '02'],
#  ['2018', '06'],
#  ['2020', '01'],
#  ['2020', '04'],
#  ['2020', '08'],
#  ['2020', '10'],
#  ['2020', '11'],
#  ['2020', '12'],
#  ['2021', '01'],
#  ['2018', '04'],
#  ['2019', '01'],
#  ['2019', '04'],
#  ['2005', '01'],
#  ['2010', '01'],
#  ['2011', '01'],
#  ['2012', '01'],
#  ['2005', '10'],
#  ['2006', '01'],
#  ['2006', '02'],
#  ['2006', '04'],
#  ['2006', '05'],
#  ['2006', '10'],
#  ['2007', '03'],
#  ['2008', '02'],
#  ['2008', '05'],
#  ['2009', '02'],
#  ['2009', '11'],
#  ['2010', '04'],
#  ['2011', '03'],
#  ['2011', '11'],
#  ['2012', '08'],
#  ['2012', '10'],
#  ['2012', '11'],
#  ['2013', '03'],
#  ['2013', '05'],
#  ['2013', '08'],
#  ['2013', '11'],
#  ['2014', '01'],
#  ['2014', '10'],
#  ['2004', '01'],
#  ['2005', '07'],
#  ['2005', '08'],
#  ['2005', '12'],
#  ['2006', '04'],
#  ['2006', '09'],
#  ['2007', '05'],
#  ['2009', '05'],
#  ['2009', '06'],
#  ['2010', '02'],
#  ['2010', '07'],
#  ['2010', '09'],
#  ['2011', '03'],
#  ['2011', '07'],
#  ['2011', '11'],
#  ['2012', '10'],
#  ['2013', '05'],
#  ['2013', '11'],
#  ['2014', '03'],
#  ['2015', '07'],
#  ['2017', '01'],
#  ['2018', '01'],
#  ['2019', '07'],
#  ['2020', '01'],
#  ['2014', '01'],
#  ['2016', '10'],
#  ['2017', '10'],
#  ['2019', '04'],
#  ['2020', '01'],
#  ['2003', '01'],
#  ['2009', '01'],
#  ['2018', '01'],
#  ['2021', '01'],
#  ['2004', '10'],
#  ['2005', '10'],
#  ['2007', '01'],
#  ['2008', '04'],
#  ['2010', '04'],
#  ['2011', '10'],
#  ['2012', '01'],
#  ['2012', '04'],
#  ['2014', '04'],
#  ['2015', '01'],
#  ['2015', '10'],
#  ['2016', '04'],
#  ['2016', '07'],
#  ['2016', '10'],
#  ['2017', '04'],
#  ['2017', '10'],
#  ['2018', '01'],
#  ['2019', '07'],
#  ['2019', '10'],
#  ['2020', '07'],
#  ['2016', '01'],
#  ['2017', '12'],
#  ['2019', '05'],
#  ['2019', '07'],
#  ['2019', '10'],
#  ['2020', '01'],
#  ['2020', '02'],
#  ['2020', '03'],
#  ['2020', '09'],
#  ['2020', '12'],
#  ['2017', '10'],
#  ['2018', '01'],
#  ['2020', '10'],
#  ['2003', '01'],
#  ['2008', '01'],
#  ['2005', '05'],
#  ['2006', '04'],
#  ['2007', '07'],
#  ['2007', '08'],
#  ['2008', '01'],
#  ['2008', '04'],
#  ['2008', '08'],
#  ['2009', '04'],
#  ['2009', '06'],
#  ['2009', '10'],
#  ['2010', '01'],
#  ['2010', '05'],
#  ['2010', '08'],
#  ['2010', '09'],
#  ['2010', '12'],
#  ['2011', '05'],
#  ['2012', '04'],
#  ['2012', '09'],
#  ['2013', '06'],
#  ['2013', '07'],
#  ['2013', '11'],
#  ['2014', '10'],
#  ['2015', '04'],
#  ['2015', '05'],
#  ['2015', '08'],
#  ['2005', '04'],
#  ['2009', '07'],
#  ['2010', '07'],
#  ['2013', '07'],
#  ['2015', '04'],
#  ['2015', '07'],
#  ['2016', '01'],
#  ['2016', '04'],
#  ['2016', '07'],
#  ['2018', '05'],
#  ['2018', '10'],
#  ['2019', '10'],
#  ['2020', '05'],
#  ['2020', '08'],
#  ['2020', '12'],
#  ['2019', '07'],
#  ['2021', '04'],
#  ['2014', '01'],
#  ['2016', '01'],
#  ['2015', '03'],
#  ['2016', '10'],
#  ['2017', '01'],
#  ['2017', '01'],
#  ['2017', '04'],
#  ['2017', '07'],
#  ['2017', '10'],
#  ['2018', '01'],
#  ['2018', '01'],
#  ['2018', '04'],
#  ['2005', '04'],
#  ['2005', '06'],
#  ['2005', '08'],
#  ['2006', '05'],
#  ['2006', '10'],
#  ['2007', '01'],
#  ['2007', '02'],
#  ['2008', '05'],
#  ['2008', '09'],
#  ['2008', '11'],
#  ['2009', '06'],
#  ['2009', '09'],
#  ['2009', '12'],
#  ['2010', '01'],
#  ['2011', '01'],
#  ['2011', '07'],
#  ['2011', '10'],
#  ['2012', '02'],
#  ['2012', '04'],
#  ['2012', '05'],
#  ['2013', '01'],
#  ['2013', '04'],
#  ['2013', '06'],
#  ['2013', '07'],
#  ['2014', '12'],
#  ['2015', '04'],
#  ['2019', '01'],
#  ['2005', '07'],
#  ['2006', '10'],
#  ['2007', '01'],
#  ['2008', '10'],
#  ['2009', '01'],
#  ['2010', '01'],
#  ['2010', '10'],
#  ['2011', '10'],
#  ['2012', '07'],
#  ['2012', '10'],
#  ['2014', '10'],
#  ['2015', '07'],
#  ['2016', '01'],
#  ['2021', '01'],
#  ['2018', '02'],
#  ['2018', '04'],
#  ['2018', '05'],
#  ['2019', '03'],
#  ['2020', '02'],
#  ['2020', '05'],
#  ['2020', '08'],
#  ['2020', '11'],
#  ['2017', '10'],
#  ['2021', '01'],
#  ['2005', '07'],
#  ['2006', '01'],
#  ['2008', '04'],
#  ['2008', '10'],
#  ['2010', '01'],
#  ['2010', '07'],
#  ['2010', '10'],
#  ['2012', '07'],
#  ['2014', '10'],
#  ['2015', '01'],
#  ['2016', '01'],
#  ['2017', '12'],
#  ['2018', '02'],
#  ['2018', '04'],
#  ['2018', '10'],
#  ['2019', '08'],
#  ['2020', '06'],
#  ['2017', '10'],
#  ['2018', '07'],
#  ['2019', '07'],
#  ['2020', '10'],
#  ['2017', '11'],
#  ['2018', '02'],
#  ['2018', '06'],
#  ['2018', '07'],
#  ['2018', '09'],
#  ['2018', '12'],
#  ['2019', '08'],
#  ['2020', '03'],
#  ['2021', '02'],
#  ['2018', '10'],
#  ['2019', '04'],
#  ['2019', '10'],
#  ['2020', '01'],
#  ['2020', '04'],
#  ['2020', '10'],
#  ['2004', '01'],
#  ['2007', '01'],
#  ['2009', '01'],
#  ['2010', '01'],
#  ['2012', '01'],
#  ['2005', '08'],
#  ['2005', '11'],
#  ['2006', '02'],
#  ['2006', '05'],
#  ['2007', '01'],
#  ['2007', '02'],
#  ['2007', '04'],
#  ['2007', '08'],
#  ['2007', '11'],
#  ['2008', '03'],
#  ['2008', '12'],
#  ['2011', '01'],
#  ['2011', '06'],
#  ['2011', '09'],
#  ['2011', '10'],
#  ['2012', '06'],
#  ['2012', '08'],
#  ['2013', '04'],
#  ['2013', '08'],
#  ['2013', '09'],
#  ['2013', '10'],
#  ['2013', '12'],
#  ['2014', '02'],
#  ['2014', '08'],
#  ['2014', '10'],
#  ['2004', '01'],
#  ['2008', '01'],
#  ['2011', '01'],
#  ['2012', '01'],
#  ['2003', '01'],
#  ['2005', '01'],
#  ['2005', '04'],
#  ['2006', '01'],
#  ['2006', '07'],
#  ['2007', '01'],
#  ['2007', '10'],
#  ['2010', '01'],
#  ['2011', '01'],
#  ['2013', '01'],
#  ['2015', '07'],
#  ['2003', '01'],
#  ['2006', '01'],
#  ['2006', '07'],
#  ['2010', '07'],
#  ['2012', '10'],
#  ['2014', '01'],
#  ['2015', '01'],
#  ['2003', '07'],
#  ['2004', '04'],
#  ['2004', '07'],
#  ['2004', '10'],
#  ['2005', '04'],
#  ['2006', '01'],
#  ['2006', '07'],
#  ['2007', '01'],
#  ['2007', '07'],
#  ['2009', '07'],
#  ['2009', '10'],
#  ['2010', '04'],
#  ['2010', '07'],
#  ['2011', '07'],
#  ['2012', '04'],
#  ['2013', '07'],
#  ['2008', '01'],
#  ['2018', '01'],
#  ['2017', '01'],
#  ['2020', '01'],
#  ['2020', '04'],
#  ['2020', '10'],
#  ['2021', '01'],
#  ['2018', '01'],
#  ['2020', '01'],
#  ['2020', '04'],
#  ['2020', '10'],
#  ['2016', '07'],
#  ['2018', '10'],
#  ['2021', '04'],
#  ['2018', '01'],
#  ['2018', '04'],
#  ['2018', '09'],
#  ['2019', '03'],
#  ['2019', '04'],
#  ['2019', '07'],
#  ['2019', '10'],
#  ['2019', '11'],
#  ['2020', '01'],
#  ['2020', '05'],
#  ['2020', '06'],
#  ['2005', '01'],
#  ['2005', '10'],
#  ['2006', '10'],
#  ['2007', '07'],
#  ['2007', '10'],
#  ['2008', '01'],
#  ['2009', '07'],
#  ['2011', '01'],
#  ['2013', '01'],
#  ['2014', '10'],
#  ['2016', '01'],
#  ['2018', '05'],
#  ['2018', '08'],
#  ['2019', '05'],
#  ['2019', '09'],
#  ['2020', '03'],
#  ['2020', '06'],
#  ['2020', '07'],
#  ['2020', '10'],
#  ['2018', '10'],
#  ['2019', '10'],
#  ['2021', '04'],
#  ['2006', '01'],
#  ['2011', '01'],
#  ['2012', '01'],
#  ['2013', '01'],
#  ['2014', '01'],
#  ['2015', '01'],
#  ['2016', '01'],
#  ['2004', '10'],
#  ['2006', '04'],
#  ['2006', '07'],
#  ['2007', '10'],
#  ['2010', '04'],
#  ['2011', '04'],
#  ['2013', '04'],
#  ['2014', '04'],
#  ['2016', '01'],
#  ['2019', '10'],
#  ['2020', '05'],
#  ['2020', '09'],
#  ['2021', '01'],
#  ['2020', '04'],
#  ['2021', '01'],
#  ['2017', '07'],
#  ['2020', '01'],
#  ['2020', '07'],
#  ['2007', '01'],
#  ['2012', '01'],
#  ['2016', '01'],
#  ['2005', '08'],
#  ['2006', '01'],
#  ['2006', '03'],
#  ['2006', '05'],
#  ['2006', '09'],
#  ['2007', '02'],
#  ['2007', '09'],
#  ['2008', '04'],
#  ['2010', '03'],
#  ['2010', '08'],
#  ['2010', '10'],
#  ['2011', '06'],
#  ['2011', '07'],
#  ['2011', '09'],
#  ['2011', '10'],
#  ['2011', '11'],
#  ['2012', '02'],
#  ['2013', '02'],
#  ['2013', '10'],
#  ['2014', '06'],
#  ['2015', '04'],
#  ['2015', '05'],
#  ['2015', '08'],
#  ['2005', '01'],
#  ['2007', '04'],
#  ['2008', '01'],
#  ['2009', '01'],
#  ['2009', '07'],
#  ['2010', '01'],
#  ['2010', '10'],
#  ['2012', '07'],
#  ['2014', '01'],
#  ['2015', '04'],
#  ['2015', '10'],
#  ['2012', '01'],
#  ['2009', '09'],
#  ['2009', '10'],
#  ['2010', '01'],
#  ['2010', '05'],
#  ['2010', '08'],
#  ['2010', '10'],
#  ['2011', '02'],
#  ['2011', '04'],
#  ['2011', '08'],
#  ['2011', '10'],
#  ['2012', '01'],
#  ['2012', '06'],
#  ['2012', '09'],
#  ['2012', '10'],
#  ['2013', '05'],
#  ['2013', '08'],
#  ['2013', '10'],
#  ['2014', '01'],
#  ['2014', '04'],
#  ['2014', '09'],
#  ['2014', '10'],
#  ['2015', '01'],
#  ['2015', '04'],
#  ['2018', '01'],
#  ['2019', '01'],
#  ['2019', '07'],
#  ['2019', '10'],
#  ['2020', '01'],
#  ['2018', '01'],
#  ['2018', '05'],
#  ['2018', '09'],
#  ['2019', '01'],
#  ['2019', '02'],
#  ['2019', '04'],
#  ['2019', '09'],
#  ['2019', '10'],
#  ['2019', '11'],
#  ['2020', '02'],
#  ['2020', '06'],
#  ['2021', '02'],
#  ['2018', '07'],
#  ['2018', '10'],
#  ['2012', '01'],
#  ['2005', '01'],
#  ['2006', '01'],
#  ['2006', '04'],
#  ['2006', '07'],
#  ['2007', '04'],
#  ['2007', '10'],
#  ['2009', '07'],
#  ['2009', '10'],
#  ['2011', '01'],
#  ['2012', '07'],
#  ['2013', '10'],
#  ['2014', '07'],
#  ['2018', '03'],
#  ['2018', '10'],
#  ['2018', '12'],
#  ['2019', '06'],
#  ['2020', '01'],
#  ['2020', '02'],
#  ['2020', '05'],
#  ['2018', '10'],
#  ['2019', '04'],
#  ['2021', '01'],
#  ['2021', '04'],
#  ['2007', '01'],
#  ['2005', '03'],
#  ['2005', '08'],
#  ['2005', '11'],
#  ['2006', '01'],
#  ['2006', '06'],
#  ['2006', '08'],
#  ['2006', '10'],
#  ['2007', '08'],
#  ['2007', '10'],
#  ['2008', '07'],
#  ['2009', '02'],
#  ['2009', '04'],
#  ['2010', '01'],
#  ['2010', '05'],
#  ['2010', '10'],
#  ['2012', '01'],
#  ['2012', '04'],
#  ['2012', '05'],
#  ['2012', '07'],
#  ['2013', '04'],
#  ['2013', '06'],
#  ['2013', '07'],
#  ['2014', '02'],
#  ['2014', '07'],
#  ['2014', '09'],
#  ['2014', '10'],
#  ['2015', '03'],
#  ['2015', '04'],
#  ['2015', '07'],
#  ['2006', '01'],
#  ['2007', '01'],
#  ['2009', '01'],
#  ['2005', '05'],
#  ['2006', '09'],
#  ['2006', '10'],
#  ['2007', '05'],
#  ['2007', '08'],
#  ['2008', '01'],
#  ['2008', '09'],
#  ['2008', '12'],
#  ['2009', '10'],
#  ['2010', '10'],
#  ['2011', '05'],
#  ['2012', '03'],
#  ['2012', '05'],
#  ['2012', '11'],
#  ['2012', '12'],
#  ['2013', '07'],
#  ['2013', '08'],
#  ['2013', '09'],
#  ['2014', '02'],
#  ['2014', '09'],
#  ['2015', '03'],
#  ['2015', '06'],
#  ['2017', '01'],
#  ['2016', '01'],
#  ['2017', '04'],
#  ['2018', '01'],
#  ['2019', '04'],
#  ['2020', '01'],
#  ['2020', '07'],
#  ['2021', '04'],
#  ['2017', '01'],
#  ['2019', '07'],
#  ['2019', '10'],
#  ['2016', '05'],
#  ['2016', '06'],
#  ['2016', '04'],
#  ['2016', '10'],
#  ['2003', '01'],
#  ['2003', '04'],
#  ['2004', '01'],
#  ['2006', '10'],
#  ['2015', '01'],
#  ['2018', '01'],
#  ['2021', '01'],
#  ['2016', '01'],
#  ['2016', '07'],
#  ['2018', '04'],
#  ['2018', '07'],
#  ['2019', '04'],
#  ['2019', '10'],
#  ['2020', '10'],
#  ['2019', '01'],
#  ['2021', '01'],
#  ['2016', '04'],
#  ['2017', '04'],
#  ['2018', '10'],
#  ['2019', '04'],
#  ['2019', '10'],
#  ['2020', '07'],
#  ['2020', '10'],
#  ['2021', '01'],
#  ['2021', '10'],
#  ['2016', '01'],
#  ['2021', '01'],
#  ['2016', '07'],
#  ['2017', '10'],
#  ['2019', '04'],
#  ['2020', '07'],
#  ['2021', '07'],
#  ['2019', '01'],
#  ['2016', '01'],
#  ['2016', '07'],
#  ['2016', '10'],
#  ['2017', '10'],
#  ['2018', '07'],
#  ['2019', '01'],
#  ['2019', '04'],
#  ['2020', '07'],
#  ['2020', '10'],
#  ['2018', '01'],
#  ['2016', '07'],
#  ['2017', '07'],
#  ['2017', '10'],
#  ['2019', '04'],
#  ['2019', '10'],
#  ['2020', '04'],
#  ['2020', '10'],
#  ['2020', '01'],
#  ['2021', '01'],
#  ['2017', '12'],
#  ...]

# %%
# worldoil_alldata[['Year'], ['Month']] = worldoil_alldata['DATE'].str.split('-',1,expand = True)
# worldoil_alldata[['Year'], ['Month']] = world_oil_data.DATE.apply(lambda x: world_oil_data.Series(str(x).split("-")))
worldoil_alldata['year']= worldoil_alldata.DATE.str.split('-').str[0].tolist()
worldoil_alldata['month']= worldoil_alldata.DATE.str.split('-').str[1].tolist()

worldoil_alldata
# Out:
#           DATE  FREQUENCY REGION_NAME  INDICATOR_NAME  VALUE INDICATOR_ID  \
# 0      2017-06    Monthly       Japan  Total products  85.70       KN.B47
# 1      2018-07    Monthly       Japan  Total products  80.10       KN.B47
# 2      2018-08    Monthly       Japan  Total products  87.00       KN.B47
# 3      2019-02    Monthly       Japan  Total products  82.40       KN.B47
# 4      2019-07    Monthly       Japan  Total products  85.30       KN.B47
# ...        ...        ...         ...             ...    ...          ...
# 24964  2003-07  Quarterly        Euro   Demand (mb/d)   8.40       KN.B21
# 24965  2004-04  Quarterly        Euro   Demand (mb/d)   8.10       KN.B21
# 24966  2005-07  Quarterly        Euro   Demand (mb/d)   8.26       KN.B21
# 24967  2006-04  Quarterly        Euro   Demand (mb/d)   7.94       KN.B21
# 24968  2007-04  Quarterly        Euro   Demand (mb/d)   7.65       KN.B21
#
#       REGION_ID REGION_NOTES REGION_REGIONID  year month
# 0            JP          NaN              JP  2017    06
# 1            JP          NaN              JP  2018    07
# 2            JP          NaN              JP  2018    08
# 3            JP          NaN              JP  2019    02
# 4            JP          NaN              JP  2019    07
# ...         ...          ...             ...   ...   ...
# 24964    KN.DE1          NaN          KN.DE1  2003    07
# 24965    KN.DE1          NaN          KN.DE1  2004    04
# 24966    KN.DE1          NaN          KN.DE1  2005    07
# 24967    KN.DE1          NaN          KN.DE1  2006    04
# 24968    KN.DE1          NaN          KN.DE1  2007    04
#
# [24969 rows x 11 columns]

# %%
df = worldoil_alldata['REGION_NOTES'].value_counts()
df = pd. DataFrame(df)
df
# Out:
#                                                     REGION_NOTES
# "Total" consist of following areas:  1. US50  2...            31

# %%
del worldoil_alldata['REGION_NOTES']
del worldoil_alldata['REGION_REGIONID']
del worldoil_alldata['REGION_ID']
del worldoil_alldata['INDICATOR_ID']
del worldoil_alldata['DATE']
worldoil_alldata
# Out:
#        FREQUENCY REGION_NAME  INDICATOR_NAME  VALUE  year month
# 0        Monthly       Japan  Total products  85.70  2017    06
# 1        Monthly       Japan  Total products  80.10  2018    07
# 2        Monthly       Japan  Total products  87.00  2018    08
# 3        Monthly       Japan  Total products  82.40  2019    02
# 4        Monthly       Japan  Total products  85.30  2019    07
# ...          ...         ...             ...    ...   ...   ...
# 24964  Quarterly        Euro   Demand (mb/d)   8.40  2003    07
# 24965  Quarterly        Euro   Demand (mb/d)   8.10  2004    04
# 24966  Quarterly        Euro   Demand (mb/d)   8.26  2005    07
# 24967  Quarterly        Euro   Demand (mb/d)   7.94  2006    04
# 24968  Quarterly        Euro   Demand (mb/d)   7.65  2007    04
#
# [24969 rows x 6 columns]

# %% [markdown]
# ### Converting dtypes of year and month to integer

# %%
worldoil_alldata = worldoil_alldata.astype({"year":int}, errors = 'raise')
worldoil_alldata = worldoil_alldata.astype({"month":int}, errors = 'raise')
worldoil_alldata.dtypes
# Out:
# FREQUENCY          object
# REGION_NAME        object
# INDICATOR_NAME     object
# VALUE             float64
# year                int32
# month               int32
# dtype: object

# %% [markdown]
# ### Understanding Data in columns for making DataFrame

# %%
df1 = worldoil_alldata ['FREQUENCY'].value_counts()
df1 = pd.DataFrame(df1)
df1
# Out:
#            FREQUENCY
# Monthly        15939
# Quarterly       6908
# Annual          2122

# %%
df2 = worldoil_alldata ['REGION_NAME'].value_counts()
df2 = pd.DataFrame(df2)
df2
# Out:
#                              REGION_NAME
# Pacific, OECD                       1456
# North America, OECD                 1455
# Canada                              1270
# United Kingdom                      1239
# United States                       1177
# ...                                  ...
# Azerbaijan                            26
# Qatar                                 26
# Kazakhstan                            26
# OPEC incl. Angola & Ecuador           24
# OPEC incl. Angola                     21
#
# [73 rows x 1 columns]

# %% [markdown]
# ### saving country / region list for DataBase users

# %%
df2.to_csv("worldoildata_allcountries.csv", index= True, header = True)

# %% [markdown]
# ### When comapred with country list used for Global emissions, the world oil database has 26 less countries but has grouped countires in regional areas like americas, latin americas etc..

# %%
df3 = worldoil_alldata ['INDICATOR_NAME'].value_counts()
df3 = pd.DataFrame(df3)
df3
# Out:
#                                              INDICATOR_NAME
# Total Supply                                           7194
# Crude oil                                              3472
# Residual fuel oil                                      1396
# Motor gasoline                                         1396
# Total                                                  1396
# Other products                                         1348
# Demand (mb/d)                                          1025
# Jet and kerosene                                        970
# Naphtha                                                 970
# LPG and ethane                                          970
# Oil Supply                                              651
# Gasoil/diesel oil                                       598
# Oil Demand                                              597
# Crude                                                   453
# Middle distillate                                       426
# Total products                                          426
# Other                                                   378
# Diesel                                                  372
# Other gasoil                                            372
# Total NGLs                                              112
# Global Biofuels                                          95
# Processing gains                                         95
# NGLs                                                     32
# Call on OPEC crude + Stock ch                            32
# Percentage of Summary Of Global Oil Demand               31
# Industry And Government Total                            27
# Industry                                                 27
# Floating storage/Oil in transit                          27
# Total Stock Stock Changes And Miscellaneous              27
# Miscellaneous to balance                                 27
# Government                                               27

# %% [markdown]
# ###  Saving Data categories for DB user

# %%
df3.to_csv("worldoildata_Querytype.csv", index= True, header = True)

# %% [markdown]
# ### Understanding data catergories to finalize Dataframe loaded in SQL that would aid in further analyzing Emissions data

# %%
# df4 = worldoil_alldata.loc[(worldoil_alldata["INDICATOR_NAME"] == "Percentage of Summary Of Global Oil Demand"), :]
# df4 = worldoil_alldata.loc[(worldoil_alldata["INDICATOR_NAME"] == "Government"), :]
# df4 = worldoil_alldata.loc[(worldoil_alldata["INDICATOR_NAME"] == "Total Stock Stock Changes And Miscellaneous"), :]
df4 = worldoil_alldata.loc[(worldoil_alldata["INDICATOR_NAME"] == "Demand (mb/d)")
                           |(worldoil_alldata["INDICATOR_NAME"] == "Oil Demand"), :]
# df4 = worldoil_alldata.loc[(worldoil_alldata["REGION_NAME"] == "United States"), :]
df4 = pd.DataFrame(df4)
# df4 = df4.sort_values["DATE"]
df4
# Out:
#        FREQUENCY    REGION_NAME INDICATOR_NAME  VALUE  year  month
# 44        Annual  Pacific, OECD  Demand (mb/d)   7.85  2010      1
# 45        Annual  Pacific, OECD  Demand (mb/d)   8.08  2012      1
# 198       Annual       Non-OECD     Oil Demand  48.90  2020      1
# 207       Annual       Non-OECD  Demand (mb/d)  49.48  2016      1
# 208    Quarterly       Non-OECD  Demand (mb/d)  49.44  2016      7
# ...          ...            ...            ...    ...   ...    ...
# 24964  Quarterly           Euro  Demand (mb/d)   8.40  2003      7
# 24965  Quarterly           Euro  Demand (mb/d)   8.10  2004      4
# 24966  Quarterly           Euro  Demand (mb/d)   8.26  2005      7
# 24967  Quarterly           Euro  Demand (mb/d)   7.94  2006      4
# 24968  Quarterly           Euro  Demand (mb/d)   7.65  2007      4
#
# [1622 rows x 6 columns]

# %%
df4a = df4["REGION_NAME"].value_counts()
df4a
# Out:
# Latin America, Non-OECD    133
# North America, OECD        113
# Pacific, OECD              113
# Other,Asia, Non-OECD        68
# OECD                        63
# Americas, Non-OECD          63
# China                       63
# Africa, Non-OECD            63
# Asia Oceania, OECD          63
# Europe, Non-OECD            63
# Europe, OECD                63
# Middle East, Non-OECD       63
# Non-OECD                    63
# World                       63
# Americas, OECD              63
# Former USSR                 63
# Euro                        36
# Brazil                      31
# India                       31
# Iran                        31
# US50                        31
# Mexico                      31
# Total                       31
# Japan                       31
# Europe                      31
# Russia                      31
# Asia, Non-OECD              31
# Korea                       31
# Canada                      31
# Saudi Arabia                31
# Name: REGION_NAME, dtype: int64

# %% [markdown]
# ### Cleaning & Organizing data for SQL - Loading org_df4 & org_worldoil_alldata in SQL. The table created in org_df4 provides the oil demand data that is related to economic health of the relative country which relates directly to emission change through the years..

# %%
df4 = df4.rename(columns = {"FREQUENCY": "Data_Interval", "REGION_NAME":"Country", "INDICATOR_NAME":"Data_Category", "VALUE": "million-bbls" })
org_df4 = df4[["year", "month", "Country", "Data_Interval", "Data_Category", "million-bbls"]]
org_df4.reset_index(drop = True, inplace = True)
org_df4
# Out:
#       year  month        Country Data_Interval  Data_Category  million-bbls
# 0     2010      1  Pacific, OECD        Annual  Demand (mb/d)          7.85
# 1     2012      1  Pacific, OECD        Annual  Demand (mb/d)          8.08
# 2     2020      1       Non-OECD        Annual     Oil Demand         48.90
# 3     2016      1       Non-OECD        Annual  Demand (mb/d)         49.48
# 4     2016      7       Non-OECD     Quarterly  Demand (mb/d)         49.44
# ...    ...    ...            ...           ...            ...           ...
# 1617  2003      7           Euro     Quarterly  Demand (mb/d)          8.40
# 1618  2004      4           Euro     Quarterly  Demand (mb/d)          8.10
# 1619  2005      7           Euro     Quarterly  Demand (mb/d)          8.26
# 1620  2006      4           Euro     Quarterly  Demand (mb/d)          7.94
# 1621  2007      4           Euro     Quarterly  Demand (mb/d)          7.65
#
# [1622 rows x 6 columns]

# %%
worldoil_alldata = worldoil_alldata.rename(columns = {"FREQUENCY": "Data_Interval", "REGION_NAME":"Country", "INDICATOR_NAME":"Data_Category", "VALUE": "million-bbls" })
org_worldoil_alldata = worldoil_alldata[["year", "month", "Country", "Data_Interval", "Data_Category", "million-bbls"]]
org_worldoil_alldata.reset_index(drop = True, inplace = True)
org_worldoil_alldata
# Out:
#        year  month Country Data_Interval   Data_Category  million-bbls
# 0      2017      6   Japan       Monthly  Total products         85.70
# 1      2018      7   Japan       Monthly  Total products         80.10
# 2      2018      8   Japan       Monthly  Total products         87.00
# 3      2019      2   Japan       Monthly  Total products         82.40
# 4      2019      7   Japan       Monthly  Total products         85.30
# ...     ...    ...     ...           ...             ...           ...
# 24964  2003      7    Euro     Quarterly   Demand (mb/d)          8.40
# 24965  2004      4    Euro     Quarterly   Demand (mb/d)          8.10
# 24966  2005      7    Euro     Quarterly   Demand (mb/d)          8.26
# 24967  2006      4    Euro     Quarterly   Demand (mb/d)          7.94
# 24968  2007      4    Euro     Quarterly   Demand (mb/d)          7.65
#
# [24969 rows x 6 columns]

# %% [markdown]
# ### Save both DataFrames to SQL

# %%
from config import password

# %%
protocol = 'postgresql'
username = 'postgres'
host = 'localhost'
port = 5432
database_name = 'Global_Emissions'
rds_connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'
engine = create_engine(rds_connection_string)
# connection = engine.connect()

# %%
engine.table_names()
# Out:
# ['Global_oil_data_iea',
#  'Global_oil_demand',
#  'Global_Agri_Greenhouse_Emissions',
#  'Global_Agri_Percent_Emissions',
#  'Global_Greenhouse_Emissions']

# %%
org_worldoil_alldata.to_sql(name='Global_oil_data_iea', con=engine, if_exists='replace', index=False)

# %%
org_df4.to_sql(name='Global_oil_demand', con=engine, if_exists='replace', index=False)

# %%
pd.read_sql_query('select * from "Global_oil_data_iea"', con=engine).head()
# Out:
#    year  month Country Data_Interval   Data_Category  million-bbls
# 0  2017      6   Japan       Monthly  Total products          85.7
# 1  2018      7   Japan       Monthly  Total products          80.1
# 2  2018      8   Japan       Monthly  Total products          87.0
# 3  2019      2   Japan       Monthly  Total products          82.4
# 4  2019      7   Japan       Monthly  Total products          85.3

# %%
pd.read_sql_query('select * from "Global_oil_demand"', con=engine).head()
# Out:
#    year  month        Country Data_Interval  Data_Category  million-bbls
# 0  2010      1  Pacific, OECD        Annual  Demand (mb/d)          7.85
# 1  2012      1  Pacific, OECD        Annual  Demand (mb/d)          8.08
# 2  2020      1       Non-OECD        Annual     Oil Demand         48.90
# 3  2016      1       Non-OECD        Annual  Demand (mb/d)         49.48
# 4  2016      7       Non-OECD     Quarterly  Demand (mb/d)         49.44
